# %%
# Project setup and imports.
# This cell makes the src folder importable and loads the libraries we need.

import sys
from pathlib import Path

# Find the project root: the folder that contains the "src" folder.
# This lets us run the notebook from the notebooks folder.
current = Path.cwd()
PROJECT_ROOT = current if (current / "src").exists() else current.parent
sys.path.insert(0, str(PROJECT_ROOT))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Our own helper modules from the src folder.
from src import config
from src import data_loading as dl
from src import preprocessing as pp
from src import evaluation as ev
from src import plotting as viz
from src import regression_models as rm

# Make sure the output folders exist before we save anything.
config.ensure_output_dirs()

print("Setup complete. Project root:", PROJECT_ROOT)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 13
#      10 PROJECT_ROOT = current if (current / "src").exists() else current.parent
#      11 sys.path.insert(0, str(PROJECT_ROOT))
# ---> 13 import numpy as np
#      14 import pandas as pd
#      15 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'
